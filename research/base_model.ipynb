# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\gupta\\Documents\\GitHub\\Brain_Tumor_Detection'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\gupta\\Documents\\GitHub\\Brain_Tumor_Detection'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class PrepareBaseModelConfig:
    root_dir: Path
    base_model_path: Path
    updated_base_model_path: Path
    params_image_size: list
    params_learning_rate: float
    params_include_top: bool
    params_weights: str
    params_classes: int
    params_optimizer: str
    params_loss: str
    params_metrics: list
    params_freeze_layers: int
    params_l2_regularizer: int
    params_dropout: int

# %%
from CNN_Classifier.constants import *
from CNN_Classifier.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self, 
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        create_directories([self.config.artifacts_root])


    def get_prepare_base_model_config(self) -> PrepareBaseModelConfig:
        config = self.config.prepare_base_model
        
        create_directories([config.root_dir])

        prepare_base_model_config = PrepareBaseModelConfig(
            root_dir=Path(config.root_dir),
            base_model_path=Path(config.base_model_path),
            updated_base_model_path=Path(config.updated_base_model_path),
            params_image_size=self.params.input_shape,
            params_learning_rate=self.params.learning_rate,
            params_include_top=self.params.include_top,
            params_weights=self.params.weights,
            params_classes=self.params.classes,
            params_optimizer= self.params.optimizer,
            params_loss= self.params.loss,
            params_metrics= self.params.metrics,
            params_freeze_layers= self.params.freeze_layers,
            params_l2_regularizer= self.params.l2_params,
            params_dropout=self.params.dropout
            
            
        )

        return prepare_base_model_config

# %%
import os
import urllib.request as request
from zipfile import ZipFile
import tensorflow as tf

# %%
import numpy as np

# %%
# class PrepareBaseModel:
#     def __init__(self, config: PrepareBaseModelConfig):
#         self.config = config


    
#     def get_base_model(self):
#         # Step 1: Load the ResNet50 model with pre-trained weights, adjusting for grayscale input (1 channel)
#         input_tensor = tf.keras.layers.Input(shape=self.config.params_image_size)  # (224, 224, 1) for grayscale input
        
#         # Load the ResNet50 model without weights for the initial build (weights=None)
#         self.model = tf.keras.applications.ResNet50(
#             input_tensor=input_tensor,
#             weights=None,  # Don't load pre-trained weights yet
#             include_top=self.config.params_include_top
#         )

#         # Step 2: Load pre-trained ResNet50 model with ImageNet weights (3 channels)
#         pre_trained_model = tf.keras.applications.ResNet50(
#             weights='imagenet',
#             include_top=False,
#             input_shape=(224, 224, 3)  # RGB input shape
#         )

#          # Step 3: Copy weights from the pre-trained model, except for the first layer
#         for layer in self.model.layers:
#             if layer.name != 'conv1_conv':  # Skip the first conv layer, which has different input shape
#                 try:
#                     layer.set_weights(pre_trained_model.get_layer(layer.name).get_weights())
#                 except:
#                     # Some layers may not have weights (like pooling or dropout), so we skip them
#                     pass


#         self.save_model(path=self.config.base_model_path, model=self.model)


    
#     @staticmethod
#     def _prepare_full_model(model, classes, freeze_layers, learning_rate,optimizer_name,loss_function, metrics):
#          # Fine-tuning: freeze layers except the first few
#         for layer in model.layers[:freeze_layers]:
#             layer.trainable = True  # Unfreeze the first few layers

#         for layer in model.layers[freeze_layers:]:
#             layer.trainable = False  # Freeze the remaining layers

#         # Add global pooling and dense layer for classification
#         x = tf.keras.layers.GlobalAveragePooling2D()(model.output)
#         prediction = tf.keras.layers.Dense(
#             units=classes,
#             activation="softmax" if classes > 2 else "sigmoid"  # Softmax for multi-class, sigmoid for binary
#         )(x)

#          # Dynamically get the optimizer class from tf.keras.optimizers
#         optimizer_class = getattr(tf.keras.optimizers, optimizer_name)

#         full_model = tf.keras.models.Model(
#             inputs=model.input,
#             outputs=prediction
#         )

#         full_model.compile(
#             optimizer=optimizer_class(learning_rate=learning_rate),
#             loss=loss_function, 
#             metrics=metrics
#         )

#         full_model.summary()
#         return full_model
    

#     def update_base_model(self):
#         self.full_model = self._prepare_full_model(
#             model=self.model,
#             classes=self.config.params_classes,
#             freeze_layers=self.config.params_freeze_layers,  # Unfreeze the first few layers
#             learning_rate=self.config.params_learning_rate,
#             optimizer_name=self.config.params_optimizer,  # Use optimizer name from config
#             loss_function=self.config.params_loss,  # Use loss function from config
#             metrics=self.config.params_metrics  # Use metrics from config
#         )

#         self.save_model(path=self.config.updated_base_model_path, model=self.full_model)

    
#     @staticmethod
#     def save_model(path: Path, model: tf.keras.Model):
#         model.save(path)

# %%
# class PrepareBaseModel:
#     def __init__(self, config):
#         self.config = config

#     def get_base_model(self):
#         # Model initialization
#         model = tf.keras.models.Sequential()
        
#         # Initial input layer
#         model.add(tf.keras.layers.Input(shape=self.config.params_image_size))  # e.g., (224, 224, 1)
        
#         # First Conv Block
#         model.add(tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu',
#                                 kernel_regularizer=tf.keras.regularizers.l2(self.config.params_l2_regularizer)))
#         model.add(tf.keras.layers.BatchNormalization())
#         model.add(tf.keras.layers.MaxPooling2D((2, 2)))
        
#         # # Second Conv Block
#         # model.add(tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu',
#         #                         kernel_regularizer=tf.keras.regularizers.l2(self.config.params_l2_regularizer)))
#         # model.add(tf.keras.layers.BatchNormalization())
#         # model.add(tf.keras.layers.MaxPooling2D((2, 2)))
        
#         # Third Conv Block
#         model.add(tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu',
#                                 kernel_regularizer=tf.keras.regularizers.l2(self.config.params_l2_regularizer)))
#         model.add(tf.keras.layers.BatchNormalization())
#         model.add(tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu',
#                                 kernel_regularizer=tf.keras.regularizers.l2(self.config.params_l2_regularizer)))
#         model.add(tf.keras.layers.BatchNormalization())
#         model.add(tf.keras.layers.MaxPooling2D((2, 2)))

#         # # Fourth Conv Block
#         # model.add(tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu',
#         #                         kernel_regularizer=tf.keras.regularizers.l2(self.config.params_l2_regularizer)))
#         # model.add(tf.keras.layers.BatchNormalization())
#         # model.add(tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu',
#         #                         kernel_regularizer=tf.keras.regularizers.l2(self.config.params_l2_regularizer)))
#         # model.add(tf.keras.layers.BatchNormalization())
#         # model.add(tf.keras.layers.MaxPooling2D((2, 2)))

#         # Global Average Pooling
#         model.add(tf.keras.layers.GlobalAveragePooling2D())
        
#         # Dense Layers with Dropout
#         model.add(tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(self.config.params_l2_regularizer)))
#         model.add(tf.keras.layers.Dropout(self.config.params_dropout))
#         model.add(tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(self.config.params_l2_regularizer)))
#         model.add(tf.keras.layers.Dropout(self.config.params_dropout))
        
#         # Output Layer
#         model.add(tf.keras.layers.Dense(self.config.params_classes, 
#                                activation="softmax" if self.config.params_classes > 2 else "sigmoid"))
        
#         self.model = model
#         self.save_model(path=self.config.base_model_path, model=self.model)

#     @staticmethod
#     def _prepare_full_model(model,learning_rate, optimizer_name, loss_function, metrics):
#         # Compile the full model
#         optimizer_class = getattr(tf.keras.optimizers, optimizer_name)
#         full_model = tf.keras.models.Model(inputs=model.input, outputs=model.output)
#         full_model.compile(
#             optimizer=optimizer_class(learning_rate=learning_rate),
#             loss=loss_function,
#             metrics=metrics
#         )

#         full_model.summary()
#         return full_model

#     def update_base_model(self):
#         self.full_model = self._prepare_full_model(
#             model=self.model,
#             learning_rate=self.config.params_learning_rate,
#             optimizer_name=self.config.params_optimizer,
#             loss_function=self.config.params_loss,
#             metrics=self.config.params_metrics
#         )
#         self.save_model(path=self.config.updated_base_model_path, model=self.full_model)

#     @staticmethod
#     def save_model(path: Path, model: tf.keras.Model):
#         model.save(path)

# %%
class PrepareBaseModel:
    def __init__(self, config: PrepareBaseModelConfig):
        self.config = config


    
    def get_base_model(self):
        # Adjust the input shape for grayscale
        input_tensor = tf.keras.layers.Input(shape=(self.config.params_image_size[0], self.config.params_image_size[1], 1))  # (300, 300, 1) for grayscale input
        
        # Convert grayscale to 3-channel by replicating the grayscale channel
        x = tf.keras.layers.Lambda(lambda x: tf.tile(x, [1, 1, 1, 3]))(input_tensor)
        
        # Load EfficientNetB3 with no top and ImageNet weights, but adjust input_tensor to have 3 channels
        base_model = tf.keras.applications.EfficientNetB3(
            include_top=self.config.params_include_top,
            weights='imagenet',  # Load with ImageNet weights
            input_tensor=x  # Pass the modified input tensor
        )
        
        # Since EfficientNetB3 expects three channels, we replicate the single grayscale channel three times
        self.model = tf.keras.models.Model(inputs=input_tensor, outputs=base_model.output)

        self.save_model(path=self.config.base_model_path, model=self.model)


    
    @staticmethod
    def _prepare_full_model(model, classes, freeze_layers, learning_rate,optimizer_name,loss_function, metrics):
         # Fine-tuning: freeze layers except the first few
        for layer in model.layers[:freeze_layers]:
            layer.trainable = True  # Unfreeze the first few layers

        for layer in model.layers[freeze_layers:]:
            layer.trainable = False  # Freeze the remaining layers

        # Add global pooling and dense layer for classification
        x = tf.keras.layers.GlobalAveragePooling2D()(model.output)
        prediction = tf.keras.layers.Dense(
            units=classes,
            activation="softmax" if classes > 2 else "sigmoid"  # Softmax for multi-class, sigmoid for binary
        )(x)

         # Dynamically get the optimizer class from tf.keras.optimizers
        optimizer_class = getattr(tf.keras.optimizers, optimizer_name)

        full_model = tf.keras.models.Model(
            inputs=model.input,
            outputs=prediction
        )

        full_model.compile(
            optimizer=optimizer_class(learning_rate=learning_rate),
            loss=loss_function, 
            metrics=metrics
        )

        full_model.summary()
        return full_model
    

    def update_base_model(self):
        self.full_model = self._prepare_full_model(
            model=self.model,
            classes=self.config.params_classes,
            freeze_layers=self.config.params_freeze_layers,  # Unfreeze the first few layers
            learning_rate=self.config.params_learning_rate,
            optimizer_name=self.config.params_optimizer,  # Use optimizer name from config
            loss_function=self.config.params_loss,  # Use loss function from config
            metrics=self.config.params_metrics  # Use metrics from config
        )

        self.save_model(path=self.config.updated_base_model_path, model=self.full_model)

    
    @staticmethod
    def save_model(path: Path, model: tf.keras.Model):
        model.save(path)

# %%
try:
    config = ConfigurationManager()
    prepare_base_model_config = config.get_prepare_base_model_config()
    prepare_base_model = PrepareBaseModel(config=prepare_base_model_config)
    prepare_base_model.get_base_model()
    prepare_base_model.update_base_model()
except Exception as e:
    raise e
# Out:
# [2024-09-13 13:43:37,553: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2024-09-13 13:43:37,566: INFO: common: yaml file: params.yaml loaded successfully]
# [2024-09-13 13:43:37,571: INFO: common: created directory at: artifacts]
# [2024-09-13 13:43:37,575: INFO: common: created directory at: artifacts/prepare_base_model]
# [2024-09-13 13:43:43,128: WARNING: saving_utils: Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.]
# c:\Users\gupta\Documents\GitHub\Brain_Tumor_Detection\cnn_venv\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 300, 300, 1)]        0         []
#
#  lambda (Lambda)             (None, 300, 300, 3)          0         ['input_9[0][0]']
#
#  rescaling_7 (Rescaling)     (None, 300, 300, 3)          0         ['lambda[0][0]']
#
#  normalization_4 (Normaliza  (None, 300, 300, 3)          7         ['rescaling_7[0][0]']
#  tion)
#
#  rescaling_8 (Rescaling)     (None, 300, 300, 3)          0         ['normalization_4[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 301, 301, 3)          0         ['rescaling_8[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 150, 150, 40)         1080      ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 150, 150, 40)         160       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 150, 150, 40)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 150, 150, 40)         360       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 150, 150, 40)         160       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 150, 150, 40)         0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 40)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 40)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 10)             410       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 40)             440       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 150, 150, 40)         0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 150, 150, 24)         960       ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 150, 150, 24)         96        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 150, 150, 24)         216       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 150, 150, 24)         96        ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 150, 150, 24)         0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 24)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 24)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 6)              150       ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 24)             168       ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 150, 150, 24)         0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 150, 150, 24)         576       ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 150, 150, 24)         96        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (Dropout)      (None, 150, 150, 24)         0         ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)           (None, 150, 150, 24)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 150, 150, 144)        3456      ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 150, 150, 144)        576       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 150, 150, 144)        0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 151, 151, 144)        0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 75, 75, 144)          1296      ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 75, 75, 144)          576       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 75, 75, 144)          0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 144)                  0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 75, 75, 144)          0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 75, 75, 32)           4608      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 75, 75, 32)           128       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 75, 75, 192)          6144      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 75, 75, 192)          768       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 75, 75, 192)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 75, 75, 192)          1728      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 75, 75, 192)          768       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 75, 75, 192)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 192)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 75, 75, 192)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 75, 75, 32)           6144      ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 75, 75, 32)           128       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 75, 75, 32)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 75, 75, 32)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 75, 75, 192)          6144      ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 75, 75, 192)          768       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 75, 75, 192)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 75, 75, 192)          1728      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 75, 75, 192)          768       ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 75, 75, 192)          0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 192)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 75, 75, 192)          0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 75, 75, 32)           6144      ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 75, 75, 32)           128       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 75, 75, 32)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 75, 75, 32)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 75, 75, 192)          6144      ['block2c_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 75, 75, 192)          768       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 75, 75, 192)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 79, 79, 192)          0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 38, 38, 192)          4800      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 38, 38, 192)          768       ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 38, 38, 192)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 192)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 38, 38, 192)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 38, 38, 48)           9216      ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 38, 38, 48)           192       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 38, 38, 288)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_dwconv (DepthwiseC  (None, 38, 38, 288)          7200      ['block3b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3b_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block3b_dwconv[0][0]']
#  tion)
#
#  block3b_activation (Activa  (None, 38, 38, 288)          0         ['block3b_bn[0][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 288)                  0         ['block3b_activation[0][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3b_se_squeeze[0][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multipl  (None, 38, 38, 288)          0         ['block3b_activation[0][0]',
#  y)                                                                  'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv  (None, 38, 38, 48)           13824     ['block3b_se_excite[0][0]']
#  2D)
#
#  block3b_project_bn (BatchN  (None, 38, 38, 48)           192       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 38, 38, 48)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 38, 38, 48)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 38, 38, 288)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_dwconv (DepthwiseC  (None, 38, 38, 288)          7200      ['block3c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3c_bn (BatchNormaliza  (None, 38, 38, 288)          1152      ['block3c_dwconv[0][0]']
#  tion)
#
#  block3c_activation (Activa  (None, 38, 38, 288)          0         ['block3c_bn[0][0]']
#  tion)
#
#  block3c_se_squeeze (Global  (None, 288)                  0         ['block3c_activation[0][0]']
#  AveragePooling2D)
#
#  block3c_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3c_se_squeeze[0][0]']
#  e)
#
#  block3c_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multipl  (None, 38, 38, 288)          0         ['block3c_activation[0][0]',
#  y)                                                                  'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv  (None, 38, 38, 48)           13824     ['block3c_se_excite[0][0]']
#  2D)
#
#  block3c_project_bn (BatchN  (None, 38, 38, 48)           192       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 38, 38, 48)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 38, 38, 48)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 38, 38, 288)          13824     ['block3c_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 38, 38, 288)          1152      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 38, 38, 288)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv_pad (ZeroPa  (None, 39, 39, 288)          0         ['block4a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block4a_dwconv (DepthwiseC  (None, 19, 19, 288)          2592      ['block4a_dwconv_pad[0][0]']
#  onv2D)
#
#  block4a_bn (BatchNormaliza  (None, 19, 19, 288)          1152      ['block4a_dwconv[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 19, 19, 288)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 288)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 19, 19, 288)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 19, 19, 96)           27648     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 19, 19, 96)           384       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 19, 19, 576)          55296     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 19, 19, 576)          2304      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 19, 19, 576)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv (DepthwiseC  (None, 19, 19, 576)          5184      ['block4b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4b_bn (BatchNormaliza  (None, 19, 19, 576)          2304      ['block4b_dwconv[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 19, 19, 576)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 576)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 576)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 24)             13848     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 576)            14400     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 19, 19, 576)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 19, 19, 96)           55296     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 19, 19, 96)           384       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 19, 19, 96)           0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 19, 19, 96)           0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 19, 19, 576)          55296     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 19, 19, 576)          2304      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 19, 19, 576)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv (DepthwiseC  (None, 19, 19, 576)          5184      ['block4c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4c_bn (BatchNormaliza  (None, 19, 19, 576)          2304      ['block4c_dwconv[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 19, 19, 576)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 576)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 576)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 24)             13848     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 576)            14400     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 19, 19, 576)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 19, 19, 96)           55296     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 19, 19, 96)           384       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 19, 19, 96)           0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 19, 19, 96)           0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 19, 19, 576)          55296     ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 19, 19, 576)          2304      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 19, 19, 576)          0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv (DepthwiseC  (None, 19, 19, 576)          5184      ['block4d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4d_bn (BatchNormaliza  (None, 19, 19, 576)          2304      ['block4d_dwconv[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 19, 19, 576)          0         ['block4d_bn[0][0]']
#  tion)
# ...
#  AveragePooling2D)
#
#  block6e_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block6e_se_squeeze[0][0]']
#  e)
#
#  block6e_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multipl  (None, 10, 10, 1392)         0         ['block6e_activation[0][0]',
#  y)                                                                  'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv  (None, 10, 10, 232)          322944    ['block6e_se_excite[0][0]']
#  2D)
#
#  block6e_project_bn (BatchN  (None, 10, 10, 232)          928       ['block6e_project_conv[0][0]']
#  ormalization)
#
#  block6e_drop (Dropout)      (None, 10, 10, 232)          0         ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)           (None, 10, 10, 232)          0         ['block6e_drop[0][0]',
#                                                                      'block6d_add[0][0]']
#
#  block6f_expand_conv (Conv2  (None, 10, 10, 1392)         322944    ['block6e_add[0][0]']
#  D)
#
#  block6f_expand_bn (BatchNo  (None, 10, 10, 1392)         5568      ['block6f_expand_conv[0][0]']
#  rmalization)
#
#  block6f_expand_activation   (None, 10, 10, 1392)         0         ['block6f_expand_bn[0][0]']
#  (Activation)
#
#  block6f_dwconv (DepthwiseC  (None, 10, 10, 1392)         34800     ['block6f_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6f_bn (BatchNormaliza  (None, 10, 10, 1392)         5568      ['block6f_dwconv[0][0]']
#  tion)
#
#  block6f_activation (Activa  (None, 10, 10, 1392)         0         ['block6f_bn[0][0]']
#  tion)
#
#  block6f_se_squeeze (Global  (None, 1392)                 0         ['block6f_activation[0][0]']
#  AveragePooling2D)
#
#  block6f_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block6f_se_squeeze[0][0]']
#  e)
#
#  block6f_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block6f_se_reshape[0][0]']
#
#  block6f_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block6f_se_reduce[0][0]']
#
#  block6f_se_excite (Multipl  (None, 10, 10, 1392)         0         ['block6f_activation[0][0]',
#  y)                                                                  'block6f_se_expand[0][0]']
#
#  block6f_project_conv (Conv  (None, 10, 10, 232)          322944    ['block6f_se_excite[0][0]']
#  2D)
#
#  block6f_project_bn (BatchN  (None, 10, 10, 232)          928       ['block6f_project_conv[0][0]']
#  ormalization)
#
#  block6f_drop (Dropout)      (None, 10, 10, 232)          0         ['block6f_project_bn[0][0]']
#
#  block6f_add (Add)           (None, 10, 10, 232)          0         ['block6f_drop[0][0]',
#                                                                      'block6e_add[0][0]']
#
#  block7a_expand_conv (Conv2  (None, 10, 10, 1392)         322944    ['block6f_add[0][0]']
#  D)
#
#  block7a_expand_bn (BatchNo  (None, 10, 10, 1392)         5568      ['block7a_expand_conv[0][0]']
#  rmalization)
#
#  block7a_expand_activation   (None, 10, 10, 1392)         0         ['block7a_expand_bn[0][0]']
#  (Activation)
#
#  block7a_dwconv (DepthwiseC  (None, 10, 10, 1392)         12528     ['block7a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7a_bn (BatchNormaliza  (None, 10, 10, 1392)         5568      ['block7a_dwconv[0][0]']
#  tion)
#
#  block7a_activation (Activa  (None, 10, 10, 1392)         0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 1392)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 10, 10, 1392)         0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 10, 10, 384)          534528    ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 10, 10, 384)          1536      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, 10, 10, 2304)         884736    ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, 10, 10, 2304)         9216      ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, 10, 10, 2304)         0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, 10, 10, 2304)         20736     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, 10, 10, 2304)         9216      ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, 10, 10, 2304)         0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 2304)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 2304)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 96)             221280    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 2304)           223488    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 10, 10, 2304)         0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 10, 10, 384)          884736    ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 10, 10, 384)          1536      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (Dropout)      (None, 10, 10, 384)          0         ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)           (None, 10, 10, 384)          0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)           (None, 10, 10, 1536)         589824    ['block7b_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 10, 10, 1536)         6144      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 10, 10, 1536)         0         ['top_bn[0][0]']
#  )
#
#  global_average_pooling2d_4  (None, 1536)                 0         ['top_activation[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_13 (Dense)            (None, 2)                    3074      ['global_average_pooling2d_4[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 10786609 (41.15 MB)
# Trainable params: 4594 (17.95 KB)
# Non-trainable params: 10782015 (41.13 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# Explanation of the Output:
#
# Model Summary:
#
# Your model has been initialized with the grayscale input shape (224, 224, 1), as shown by the InputLayer entry (input_4 (InputLayer)).
# The first layer (conv1_conv (Conv2D)) has been successfully adapted to work with grayscale input (1 channel). The output shape of this layer is (112, 112, 64), which matches the expected output for ResNet-50's architecture.
# The total number of parameters (Total params: 23,585,538) and the breakdown into trainable and non-trainable parameters seem appropriate for a model like ResNet-50.
#
# Warnings:
#
# The warning Compiled the loaded model, but the compiled metrics have yet to be built is a standard message. It indicates that while the model has been compiled, you haven't yet called .fit() or .evaluate() on the model, so the metrics have not been initialized. This will resolve itself once you start training or evaluating the model.
#
# Trainable vs Non-Trainable Parameters:
#
# It looks like the majority of the model's parameters are non-trainable (23573824 non-trainable params), which is expected since most of the layers were frozen. Only a small portion (11714 trainable params) is trainable, likely from the layers that you have unfrozen for fine-tuning.
# This is good because you’re leveraging the pre-trained weights from ImageNet, while fine-tuning only specific layers.
